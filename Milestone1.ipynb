# %%
import requests
import pandas as pd

# %%
Saiphe2018_df = pd.read_csv('./est18-la.txt',
                        sep=r"\s+",
                        header=None,
                        skiprows = 1,
                        index_col=False,
                        names=["FIPS State Code", "FIPS county code", "Estimate of people of all ages in poverty", "90% confidence interval lower bound of estimate of people of all ages in poverty", "90% confidence interval upper bound of estimate of people of all ages in poverty", "Estimated percent of people of all ages in poverty",
                               "90% confidence interval lower bound of estimate of percent of people of all ages in poverty", "90% confidence interval upper bound of estimate of percent of people of all ages in poverty", " Estimate of people age 0-17 in poverty", 
                               "90% confidence interval lower bound of estimate of people age 0-17 in poverty", "90% confidence interval upper bound of estimate of people age 0-17 in poverty", "Estimated percent of people age 0-17 in poverty", 
                              "90% confidence interval lower bound of estimate of percent of people age 0-17 in poverty", "90% confidence interval upper bound of estimate of percent of people age 0-17 in poverty", "Estimate of related children age 5-17 in families in poverty", 
                              "90% confidence interval lower bound of estimate of related children age 5-17 in families in poverty", "90% confidence interval upper bound of estimate of related children age 5-17 in families in poverty", 
                               "Estimated percent of related children age 5-17 in families in poverty", "90% confidence interval lower bound of estimate of percent of related children age 5-17 in families in poverty", 
                              "90% confidence interval upper bound of estimate of percent of related children age 5-17 in families in poverty", "Estimate of median household income", "90% confidence interval lower bound of estimate of median household income", 
                              "90% confidence interval upper bound of estimate of median household income", "State or county name", "Two-letter Postal State abbreviation", "Tag"] 
                           )
Saiphe2018_df["Year"] = 2018

Saiphe2017_df = pd.read_csv('./est17-la.txt',
                        sep=r"\s+",
                        header=None,
                        skiprows = 1,
                        index_col=False,
                        names=["FIPS State Code", "FIPS county code", "Estimate of people of all ages in poverty", "90% confidence interval lower bound of estimate of people of all ages in poverty", "90% confidence interval upper bound of estimate of people of all ages in poverty", "Estimated percent of people of all ages in poverty",
                               "90% confidence interval lower bound of estimate of percent of people of all ages in poverty", "90% confidence interval upper bound of estimate of percent of people of all ages in poverty", " Estimate of people age 0-17 in poverty", 
                               "90% confidence interval lower bound of estimate of people age 0-17 in poverty", "90% confidence interval upper bound of estimate of people age 0-17 in poverty", "Estimated percent of people age 0-17 in poverty", 
                              "90% confidence interval lower bound of estimate of percent of people age 0-17 in poverty", "90% confidence interval upper bound of estimate of percent of people age 0-17 in poverty", "Estimate of related children age 5-17 in families in poverty", 
                              "90% confidence interval lower bound of estimate of related children age 5-17 in families in poverty", "90% confidence interval upper bound of estimate of related children age 5-17 in families in poverty", 
                               "Estimated percent of related children age 5-17 in families in poverty", "90% confidence interval lower bound of estimate of percent of related children age 5-17 in families in poverty", 
                              "90% confidence interval upper bound of estimate of percent of related children age 5-17 in families in poverty", "Estimate of median household income", "90% confidence interval lower bound of estimate of median household income", 
                              "90% confidence interval upper bound of estimate of median household income", "State or county name", "Two-letter Postal State abbreviation", "Tag"] 
                           )
Saiphe2017_df["Year"] = 2017

Saiphe2016_df = pd.read_csv('./est16-la.txt',
                        sep=r"\s+",
                        header=None,
                        skiprows = 1,
                        index_col=False,
                        names=["FIPS State Code", "FIPS county code", "Estimate of people of all ages in poverty", "90% confidence interval lower bound of estimate of people of all ages in poverty", "90% confidence interval upper bound of estimate of people of all ages in poverty", "Estimated percent of people of all ages in poverty",
                               "90% confidence interval lower bound of estimate of percent of people of all ages in poverty", "90% confidence interval upper bound of estimate of percent of people of all ages in poverty", " Estimate of people age 0-17 in poverty", 
                               "90% confidence interval lower bound of estimate of people age 0-17 in poverty", "90% confidence interval upper bound of estimate of people age 0-17 in poverty", "Estimated percent of people age 0-17 in poverty", 
                              "90% confidence interval lower bound of estimate of percent of people age 0-17 in poverty", "90% confidence interval upper bound of estimate of percent of people age 0-17 in poverty", "Estimate of related children age 5-17 in families in poverty", 
                              "90% confidence interval lower bound of estimate of related children age 5-17 in families in poverty", "90% confidence interval upper bound of estimate of related children age 5-17 in families in poverty", 
                               "Estimated percent of related children age 5-17 in families in poverty", "90% confidence interval lower bound of estimate of percent of related children age 5-17 in families in poverty", 
                              "90% confidence interval upper bound of estimate of percent of related children age 5-17 in families in poverty", "Estimate of median household income", "90% confidence interval lower bound of estimate of median household income", 
                              "90% confidence interval upper bound of estimate of median household income", "State or county name", "Two-letter Postal State abbreviation", "Tag"] 
                           )
Saiphe2016_df["Year"] = 2016

Saiphe2015_df = pd.read_csv('./est15-la.txt',
                        sep=r"\s+",
                        header=None,
                        skiprows = 1,
                        index_col=False,
                        names=["FIPS State Code", "FIPS county code", "Estimate of people of all ages in poverty", "90% confidence interval lower bound of estimate of people of all ages in poverty", "90% confidence interval upper bound of estimate of people of all ages in poverty", "Estimated percent of people of all ages in poverty",
                               "90% confidence interval lower bound of estimate of percent of people of all ages in poverty", "90% confidence interval upper bound of estimate of percent of people of all ages in poverty", " Estimate of people age 0-17 in poverty", 
                               "90% confidence interval lower bound of estimate of people age 0-17 in poverty", "90% confidence interval upper bound of estimate of people age 0-17 in poverty", "Estimated percent of people age 0-17 in poverty", 
                              "90% confidence interval lower bound of estimate of percent of people age 0-17 in poverty", "90% confidence interval upper bound of estimate of percent of people age 0-17 in poverty", "Estimate of related children age 5-17 in families in poverty", 
                              "90% confidence interval lower bound of estimate of related children age 5-17 in families in poverty", "90% confidence interval upper bound of estimate of related children age 5-17 in families in poverty", 
                               "Estimated percent of related children age 5-17 in families in poverty", "90% confidence interval lower bound of estimate of percent of related children age 5-17 in families in poverty", 
                              "90% confidence interval upper bound of estimate of percent of related children age 5-17 in families in poverty", "Estimate of median household income", "90% confidence interval lower bound of estimate of median household income", 
                              "90% confidence interval upper bound of estimate of median household income", "State or county name", "Two-letter Postal State abbreviation", "Tag"] 
                           )
Saiphe2015_df["Year"] = 2015

Saiphe2014_df = pd.read_csv('./est14-la.txt',
                        sep=r"\s+",
                        header=None,
                        skiprows = 1,
                        index_col=False,
                        names=["FIPS State Code", "FIPS county code", "Estimate of people of all ages in poverty", "90% confidence interval lower bound of estimate of people of all ages in poverty", "90% confidence interval upper bound of estimate of people of all ages in poverty", "Estimated percent of people of all ages in poverty",
                               "90% confidence interval lower bound of estimate of percent of people of all ages in poverty", "90% confidence interval upper bound of estimate of percent of people of all ages in poverty", " Estimate of people age 0-17 in poverty", 
                               "90% confidence interval lower bound of estimate of people age 0-17 in poverty", "90% confidence interval upper bound of estimate of people age 0-17 in poverty", "Estimated percent of people age 0-17 in poverty", 
                              "90% confidence interval lower bound of estimate of percent of people age 0-17 in poverty", "90% confidence interval upper bound of estimate of percent of people age 0-17 in poverty", "Estimate of related children age 5-17 in families in poverty", 
                              "90% confidence interval lower bound of estimate of related children age 5-17 in families in poverty", "90% confidence interval upper bound of estimate of related children age 5-17 in families in poverty", 
                               "Estimated percent of related children age 5-17 in families in poverty", "90% confidence interval lower bound of estimate of percent of related children age 5-17 in families in poverty", 
                              "90% confidence interval upper bound of estimate of percent of related children age 5-17 in families in poverty", "Estimate of median household income", "90% confidence interval lower bound of estimate of median household income", 
                              "90% confidence interval upper bound of estimate of median household income", "State or county name", "Two-letter Postal State abbreviation", "Tag"] 
                           )
Saiphe2014_df["Year"] = 2014

Saiphe2013_df = pd.read_csv('./est13-la.txt',
                        sep=r"\s+",
                        header=None,
                        skiprows = 1,
                        index_col=False,
                        names=["FIPS State Code", "FIPS county code", "Estimate of people of all ages in poverty", "90% confidence interval lower bound of estimate of people of all ages in poverty", "90% confidence interval upper bound of estimate of people of all ages in poverty", "Estimated percent of people of all ages in poverty",
                               "90% confidence interval lower bound of estimate of percent of people of all ages in poverty", "90% confidence interval upper bound of estimate of percent of people of all ages in poverty", " Estimate of people age 0-17 in poverty", 
                               "90% confidence interval lower bound of estimate of people age 0-17 in poverty", "90% confidence interval upper bound of estimate of people age 0-17 in poverty", "Estimated percent of people age 0-17 in poverty", 
                              "90% confidence interval lower bound of estimate of percent of people age 0-17 in poverty", "90% confidence interval upper bound of estimate of percent of people age 0-17 in poverty", "Estimate of related children age 5-17 in families in poverty", 
                              "90% confidence interval lower bound of estimate of related children age 5-17 in families in poverty", "90% confidence interval upper bound of estimate of related children age 5-17 in families in poverty", 
                               "Estimated percent of related children age 5-17 in families in poverty", "90% confidence interval lower bound of estimate of percent of related children age 5-17 in families in poverty", 
                              "90% confidence interval upper bound of estimate of percent of related children age 5-17 in families in poverty", "Estimate of median household income", "90% confidence interval lower bound of estimate of median household income", 
                              "90% confidence interval upper bound of estimate of median household income", "State or county name", "Two-letter Postal State abbreviation", "Tag"] 
                           )
Saiphe2013_df["Year"] = 2013

Saiphe2012_df = pd.read_csv('./est12-la.txt',
                        sep=r"\s+",
                        header=None,
                        skiprows = 1,
                        index_col=False,
                        names=["FIPS State Code", "FIPS county code", "Estimate of people of all ages in poverty", "90% confidence interval lower bound of estimate of people of all ages in poverty", "90% confidence interval upper bound of estimate of people of all ages in poverty", "Estimated percent of people of all ages in poverty",
                               "90% confidence interval lower bound of estimate of percent of people of all ages in poverty", "90% confidence interval upper bound of estimate of percent of people of all ages in poverty", " Estimate of people age 0-17 in poverty", 
                               "90% confidence interval lower bound of estimate of people age 0-17 in poverty", "90% confidence interval upper bound of estimate of people age 0-17 in poverty", "Estimated percent of people age 0-17 in poverty", 
                              "90% confidence interval lower bound of estimate of percent of people age 0-17 in poverty", "90% confidence interval upper bound of estimate of percent of people age 0-17 in poverty", "Estimate of related children age 5-17 in families in poverty", 
                              "90% confidence interval lower bound of estimate of related children age 5-17 in families in poverty", "90% confidence interval upper bound of estimate of related children age 5-17 in families in poverty", 
                               "Estimated percent of related children age 5-17 in families in poverty", "90% confidence interval lower bound of estimate of percent of related children age 5-17 in families in poverty", 
                              "90% confidence interval upper bound of estimate of percent of related children age 5-17 in families in poverty", "Estimate of median household income", "90% confidence interval lower bound of estimate of median household income", 
                              "90% confidence interval upper bound of estimate of median household income", "State or county name", "Two-letter Postal State abbreviation", "Tag"] 
                           )
Saiphe2012_df["Year"] = 2012

Saiphe2011_df = pd.read_csv('./est11-la.txt',
                        sep=r"\s+",
                        header=None,
                        skiprows = 1,
                        index_col=False,
                        names=["FIPS State Code", "FIPS county code", "Estimate of people of all ages in poverty", "90% confidence interval lower bound of estimate of people of all ages in poverty", "90% confidence interval upper bound of estimate of people of all ages in poverty", "Estimated percent of people of all ages in poverty",
                               "90% confidence interval lower bound of estimate of percent of people of all ages in poverty", "90% confidence interval upper bound of estimate of percent of people of all ages in poverty", " Estimate of people age 0-17 in poverty", 
                               "90% confidence interval lower bound of estimate of people age 0-17 in poverty", "90% confidence interval upper bound of estimate of people age 0-17 in poverty", "Estimated percent of people age 0-17 in poverty", 
                              "90% confidence interval lower bound of estimate of percent of people age 0-17 in poverty", "90% confidence interval upper bound of estimate of percent of people age 0-17 in poverty", "Estimate of related children age 5-17 in families in poverty", 
                              "90% confidence interval lower bound of estimate of related children age 5-17 in families in poverty", "90% confidence interval upper bound of estimate of related children age 5-17 in families in poverty", 
                               "Estimated percent of related children age 5-17 in families in poverty", "90% confidence interval lower bound of estimate of percent of related children age 5-17 in families in poverty", 
                              "90% confidence interval upper bound of estimate of percent of related children age 5-17 in families in poverty", "Estimate of median household income", "90% confidence interval lower bound of estimate of median household income", 
                              "90% confidence interval upper bound of estimate of median household income", "State or county name", "Two-letter Postal State abbreviation", "Tag"] 
                           )
Saiphe2011_df["Year"] = 2011

Saiphe2010_df = pd.read_csv('./est10-la.txt',
                        sep=r"\s+",
                        header=None,
                        skiprows = 1,
                        index_col=False,
                        names=["FIPS State Code", "FIPS county code", "Estimate of people of all ages in poverty", "90% confidence interval lower bound of estimate of people of all ages in poverty", "90% confidence interval upper bound of estimate of people of all ages in poverty", "Estimated percent of people of all ages in poverty",
                               "90% confidence interval lower bound of estimate of percent of people of all ages in poverty", "90% confidence interval upper bound of estimate of percent of people of all ages in poverty", " Estimate of people age 0-17 in poverty", 
                               "90% confidence interval lower bound of estimate of people age 0-17 in poverty", "90% confidence interval upper bound of estimate of people age 0-17 in poverty", "Estimated percent of people age 0-17 in poverty", 
                              "90% confidence interval lower bound of estimate of percent of people age 0-17 in poverty", "90% confidence interval upper bound of estimate of percent of people age 0-17 in poverty", "Estimate of related children age 5-17 in families in poverty", 
                              "90% confidence interval lower bound of estimate of related children age 5-17 in families in poverty", "90% confidence interval upper bound of estimate of related children age 5-17 in families in poverty", 
                               "Estimated percent of related children age 5-17 in families in poverty", "90% confidence interval lower bound of estimate of percent of related children age 5-17 in families in poverty", 
                              "90% confidence interval upper bound of estimate of percent of related children age 5-17 in families in poverty", "Estimate of median household income", "90% confidence interval lower bound of estimate of median household income", 
                              "90% confidence interval upper bound of estimate of median household income", "State or county name", "Two-letter Postal State abbreviation", "Tag"] 
                           )
Saiphe2010_df["Year"] = 2010
Saiphe2010_df.head()
# Out:
#    FIPS State Code  FIPS county code  \
# 0               22                 1
# 1               22                 3
# 2               22                 5
# 3               22                 7
# 4               22                 9
#
#    Estimate of people of all ages in poverty  \
# 0                                      12760
# 1                                       4374
# 2                                      13622
# 3                                       3858
# 4                                       8350
#
#    90% confidence interval lower bound of estimate of people of all ages in poverty  \
# 0                                              10650
# 1                                               3404
# 2                                              11651
# 3                                               2951
# 4                                               6640
#
#    90% confidence interval upper bound of estimate of people of all ages in poverty  \
# 0                                              14870
# 1                                               5344
# 2                                              15593
# 3                                               4765
# 4                                              10060
#
#    Estimated percent of people of all ages in poverty  \
# 0                                               21.0
# 1                                               20.4
# 2                                               12.8
# 3                                               16.7
# 4                                               21.6
#
#    90% confidence interval lower bound of estimate of percent of people of all ages in poverty  \
# 0                                               17.5
# 1                                               15.9
# 2                                               11.0
# 3                                               12.8
# 4                                               17.2
#
#    90% confidence interval upper bound of estimate of percent of people of all ages in poverty  \
# 0                                               24.5
# 1                                               24.9
# 2                                               14.6
# 3                                               20.6
# 4                                               26.0
#
#     Estimate of people age 0-17 in poverty  \
# 0                                     4886
# 1                                     1539
# 2                                     5668
# 3                                     1324
# 4                                     3009
#
#    90% confidence interval lower bound of estimate of people age 0-17 in poverty  \
# 0                                               3958
# 1                                               1209
# 2                                               4867
# 3                                                990
# 4                                               2302
#
#    ...  Estimated percent of related children age 5-17 in families in poverty  \
# 0  ...                                               27.1
# 1  ...                                               23.2
# 2  ...                                               15.3
# 3  ...                                               20.5
# 4  ...                                               27.9
#
#    90% confidence interval lower bound of estimate of percent of related children age 5-17 in families in poverty  \
# 0                                               21.8
# 1                                               17.8
# 2                                               12.6
# 3                                               15.2
# 4                                               20.7
#
#    90% confidence interval upper bound of estimate of percent of related children age 5-17 in families in poverty  \
# 0                                               32.4
# 1                                               28.6
# 2                                               18.0
# 3                                               25.8
# 4                                               35.1
#
#    Estimate of median household income  \
# 0                                36814
# 1                                35711
# 2                                62069
# 3                                43503
# 4                                31523
#
#    90% confidence interval lower bound of estimate of median household income  \
# 0                                              33728
# 1                                              33319
# 2                                              57154
# 3                                              39810
# 4                                              29209
#
#    90% confidence interval upper bound of estimate of median household income  \
# 0                                              39900
# 1                                              38103
# 2                                              66984
# 3                                              47196
# 4                                              33837
#
#    State or county name  Two-letter Postal State abbreviation           Tag  \
# 0          AcadiaParish                                    LA  est10_LA.txt
# 1           AllenParish                                    LA  est10_LA.txt
# 2       AscensionParish                                    LA  est10_LA.txt
# 3      AssumptionParish                                    LA  est10_LA.txt
# 4       AvoyellesParish                                    LA  est10_LA.txt
#
#    Year
# 0  2010
# 1  2010
# 2  2010
# 3  2010
# 4  2010
#
# [5 rows x 27 columns]

# %%
Saiphe_all = pd.concat([Saiphe2010_df, Saiphe2011_df, Saiphe2012_df, Saiphe2013_df, Saiphe2014_df, 
                        Saiphe2015_df, Saiphe2016_df, Saiphe2017_df, Saiphe2018_df])
Saiphe_all = Saiphe_all.drop(['FIPS State Code','Two-letter Postal State abbreviation', 'Tag',"Estimate of people of all ages in poverty", 
           "90% confidence interval lower bound of estimate of people of all ages in poverty", 
           "90% confidence interval upper bound of estimate of people of all ages in poverty", 
           "Estimated percent of people of all ages in poverty",
           "90% confidence interval lower bound of estimate of percent of people of all ages in poverty", 
           "90% confidence interval upper bound of estimate of percent of people of all ages in poverty",
          "Estimate of median household income", "90% confidence interval lower bound of estimate of median household income", 
            "90% confidence interval upper bound of estimate of median household income",
                              "Estimate of related children age 5-17 in families in poverty", 
                              "90% confidence interval lower bound of estimate of related children age 5-17 in families in poverty",
                              "90% confidence interval upper bound of estimate of related children age 5-17 in families in poverty", 
                               "Estimated percent of related children age 5-17 in families in poverty",
                              "90% confidence interval lower bound of estimate of percent of related children age 5-17 in families in poverty", 
                              "90% confidence interval upper bound of estimate of percent of related children age 5-17 in families in poverty"], axis=1)

# Created new IDs to keep in the dataframe
id_vars = ['FIPS county code', 'State or county name', 'Year']

# Melt dataset with metrics as row values instead of columns 

df = pd.melt(frame=Saiphe_all,id_vars=id_vars, var_name="Type_Stat", value_name="Statistic")

#FIPS County, Age Range, Estimate in Poverty, 90% Conf. Upper Bound, 90% Conf. Lower Bound, Parish, Year

#Use regex to pull out the age range
df["Age_Range"] = df['Type_Stat'].str.extract('(.\d.\d.)', expand=True)

#Use regex to pull out whether its the upper bound, lower bound, or neither
#df['Estimate'] = df['Type_Stat'].str.extract('\d\d.\sconfidence\sinterval\s([a-z][a-z][a-z][a-z][a-z]\sbound)', expand=True)

#Fill all non upper and lower bounds with "Num in Poverty"
#df = df.fillna('Num in Poverty')

#Fill the statistics in by type
#df['Num in Poverty'] = df[df['Estimate']=='Num in Poverty'].Statistic
#df['Lower Bound'] = df[df['Estimate']=='lower bound'].Statistic
#df['Upper Bound'] = df[df['Estimate']=='upper bound'].Statistic

#drop columns and try to combine the 3 types of statistics into single rows
#df.drop(['Type_Stat', 'Statistic', 'Estimate'], axis=1)
df
# Out:
#       FIPS county code  State or county name  Year  \
# 0                    1          AcadiaParish  2010
# 1                    3           AllenParish  2010
# 2                    5       AscensionParish  2010
# 3                    7      AssumptionParish  2010
# 4                    9       AvoyellesParish  2010
# ...                ...                   ...   ...
# 3451               119         WebsterParish  2018
# 3452               121  WestBatonRougeParish  2018
# 3453               123     WestCarrollParish  2018
# 3454               125   WestFelicianaParish  2018
# 3455               127            WinnParish  2018
#
#                                               Type_Stat  Statistic Age_Range
# 0                Estimate of people age 0-17 in poverty     4886.0      0-17
# 1                Estimate of people age 0-17 in poverty     1539.0      0-17
# 2                Estimate of people age 0-17 in poverty     5668.0      0-17
# 3                Estimate of people age 0-17 in poverty     1324.0      0-17
# 4                Estimate of people age 0-17 in poverty     3009.0      0-17
# ...                                                 ...        ...       ...
# 3451  90% confidence interval upper bound of estimat...       41.3      0-17
# 3452  90% confidence interval upper bound of estimat...       25.7      0-17
# 3453  90% confidence interval upper bound of estimat...       42.6      0-17
# 3454  90% confidence interval upper bound of estimat...       24.5      0-17
# 3455  90% confidence interval upper bound of estimat...       37.1      0-17
#
# [3456 rows x 6 columns]

# %%
#me trying to get them to merge
terrible = df[['FIPS county code', 'Num in Poverty']]
terrible = terrible.set_index('FIPS county code')
terrible = terrible.merge(df[['FIPS county code', 'Lower Bound']], on='FIPS county code', how='inner')
terrible
# Out:
#         FIPS county code  Num in Poverty  Lower Bound
# 0                      1          4886.0          NaN
# 1                      1          4886.0          NaN
# 2                      1          4886.0          NaN
# 3                      1          4886.0          NaN
# 4                      1          4886.0          NaN
# ...                  ...             ...          ...
# 746491               127             NaN          NaN
# 746492               127             NaN          NaN
# 746493               127             NaN          NaN
# 746494               127             NaN          NaN
# 746495               127             NaN          NaN
#
# [746496 rows x 3 columns]
