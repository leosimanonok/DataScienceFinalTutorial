# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('./Data/cleaned_race_data.csv')

# %%
df_2010 = df.loc[df["Year"] == 2010]
df_2018 = df.loc[df["Year"] == 2018]

df_2010["Percent Black"] = df_2010["Black"] / df_2010["Total Population"]
df_2018["Percent Black"] = df_2018["Black"] / df_2018["Total Population"]

df = df_2010["Geo_ID"]
# Out:
#       Unnamed: 0       Geo_ID  Census Tract  Total Population  White  Black  \
# 0              0  22071006000          60.0               449    164    179
# 1              1  22071006300          63.0              1340    283    843
# 2              2  22071006400          64.0              2118   1273    770
# 3              3  22071006500          65.0              2126    933   1031
# 4              4  22071006900          69.0               773      0    773
# ...          ...          ...           ...               ...    ...    ...
# 1588        1588  22071014400         144.0              1723   1177    477
# 1589        1589  22071014500         145.0              2516    332   2173
# 1590        1590  22071980000        9800.0                10      7      1
# 1591        1591  22071980100        9801.0                 0      0      0
# 1592        1592  22071990000        9900.0                 0      0      0
#
#       American Indian and Alask Native  Asian  \
# ...
